# %% [markdown]
# <a href="https://colab.research.google.com/github/kvbicki/ml-pyton-course/blob/main/Lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 2.1: Download and load the Exercise and Fitness Metrics Dataset into the Colab.
# Take a look at the dataset and its features. Prepare some basic plots and check the
# distribution of the features. Discuss your observations with your team (all team members
# should contribute to this task). Be ready to present your conclusions and discuss them with
# the teacher.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data = pd.read_csv('/content/sample_data/exercise_dataset.csv')

data.head()
# Out:
#    ID     Exercise  Calories Burn  Dream Weight  Actual Weight  Age  Gender  \
# 0   1   Exercise 2     286.959851     91.892531      96.301115   45    Male
# 1   2   Exercise 7     343.453036     64.165097      61.104668   25    Male
# 2   3   Exercise 4     261.223465     70.846224      71.766724   20    Male
# 3   4   Exercise 5     127.183858     79.477008      82.984456   33    Male
# 4   5  Exercise 10     416.318374     89.960226      85.643174   29  Female
#
#    Duration  Heart Rate        BMI Weather Conditions  Exercise Intensity
# 0        37         170  29.426275              Rainy                   5
# 1        43         142  21.286346              Rainy                   5
# 2        20         148  27.899592             Cloudy                   4
# 3        39         170  33.729552              Sunny                  10
# 4        34         118  23.286113             Cloudy                   3

# %%
data.describe()
# Out:
#                 ID  Calories Burn  Dream Weight  Actual Weight          Age  \
# count  3864.000000    3864.000000   3864.000000    3864.000000  3864.000000
# mean   1932.500000     301.861806     75.139263      75.188440    39.621118
# std    1115.585048     115.828604     14.545824      14.845511    12.521721
# min       1.000000     100.009403     50.001984      45.783747    18.000000
# 25%     966.750000     202.168837     62.373585      62.476906    29.000000
# 50%    1932.500000     299.742508     75.522136      75.544407    40.000000
# 75%    2898.250000     404.143688     87.707989      88.105767    51.000000
# max    3864.000000     499.859262     99.985355     104.309600    60.000000
#
#           Duration   Heart Rate          BMI  Exercise Intensity
# count  3864.000000  3864.000000  3864.000000         3864.000000
# mean     40.190994   139.777950    26.801977            5.457298
# std      11.765957    23.447528     4.746745            2.850896
# ...

# %%
plt.figure(figsize=(8,6))
sns.histplot(data=data, x='Age', hue='Gender', multiple='dodge')
plt.title('Distribution of Age by Gender')
plt.xlabel('Age')
plt.ylabel('Number of Participants')
plt.show()

plt.figure(figsize=(8,6))
sns.scatterplot(data=data, x='Duration', y='Calories Burn', hue='BMI', palette='viridis')
plt.title('Duration vs Calories Burn colored by Weight')
plt.xlabel('Duration (minutes)')
plt.ylabel('Calories Burn')
plt.grid(True)
plt.show()


plt.figure(figsize=(8,6))
sns.boxplot(data=data, x='Exercise Intensity', y='Calories Burn')
plt.title('Calories Burn by Exercise Intensity')
plt.xlabel('Exercise Intensity')
plt.ylabel('Calories Burn')
plt.show()



cor = data.select_dtypes(include=[float, int]).corr()
plt.figure(figsize=(8,6))
sns.heatmap(cor, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Task 2.2: Biases and assumptions
# Prepare a list of possible biases or assumptions you have as you begin this task. Discuss this
# issue within your team (all team members should contribute to this task). Store this list for
# further use and interpretation of results in the latter part of the project.

# %% [markdown]
# About dataset:
# * features are not correlating with each other in 1D
# * there is not height feature for calculating bmi
#
# Biases:
# * when was the weight checked
# * different values of bmi, weight etc. depending on sex
# * how was the weather measured, calories burn
#
# Asumptions:
# * intensity is colarated with calorie burn
# * duration is colarated with calorie burn
# * men perform more intense exercises than women.

# %%
# %reset -f

# %% [markdown]
# Task 2.3: Related work
# Look for information about your project dataset. Enumerate all the work done previously
# on this dataset by others, describe its contents (what was done, what libraries or
# programming languages were used, the goals of the analyses, and the general conclusions
# obtained by the authors).
#
#
# One notable project explored the correlations between study time, extracurricular activities, sleep, social life, physical activity, and other factors. The study began with data loading, cleaning, and preprocessing, followed by extensive exploratory data analysis (EDA) using various visualization techniques such as heatmaps, pair plots, histograms, and count plots to identify patterns and relationships among variables.
#
# For predictive modeling, a simple linear regression model was developed to forecast students' GPA based on numerical features extracted from the dataset. The model treated GPA as the target variable and the remaining numerical attributes as predictors. The dataset was split into training and testing subsets to evaluate model performance.
#
# The analysis was primarily implemented in Python, leveraging libraries such as pandas for data manipulation, seaborn and matplotlib for visualization, and scikit-learn for predictive modeling.
#
# The general conclusion from the study emphasized the importance of various daily activities on academic performance. While the linear regression model showed promising results, the authors suggested that future work could explore non-linear relationships, more advanced machine learning models, and integration of external data sources to provide broader insights.

# %% [markdown]
# Task 2.5: Dataset loading
# Download your project dataset, store it in your Google Drive, and then connect it to your
# Colab account. Show the description of the dataset to ensure its correct connection to your
# code

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data = pd.read_csv('/content/sample_data/student_lifestyle_dataset.csv')

data.head()
# Out:
#    Student_ID  Study_Hours_Per_Day  Extracurricular_Hours_Per_Day  \
# 0           1                  6.9                            3.8
# 1           2                  5.3                            3.5
# 2           3                  5.1                            3.9
# 3           4                  6.5                            2.1
# 4           5                  8.1                            0.6
#
#    Sleep_Hours_Per_Day  Social_Hours_Per_Day  Physical_Activity_Hours_Per_Day  \
# 0                  8.7                   2.8                              1.8
# 1                  8.0                   4.2                              3.0
# 2                  9.2                   1.2                              4.6
# 3                  7.2                   1.7                              6.5
# 4                  6.5                   2.2                              6.6
#
#     GPA Stress_Level
# 0  2.99     Moderate
# 1  2.75          Low
# 2  2.67          Low
# ...

# %%
data.describe()
# Out:
#         Student_ID  Study_Hours_Per_Day  Extracurricular_Hours_Per_Day  \
# count  2000.000000          2000.000000                    2000.000000
# mean   1000.500000             7.475800                       1.990100
# std     577.494589             1.423888                       1.155855
# min       1.000000             5.000000                       0.000000
# 25%     500.750000             6.300000                       1.000000
# 50%    1000.500000             7.400000                       2.000000
# 75%    1500.250000             8.700000                       3.000000
# max    2000.000000            10.000000                       4.000000
#
#        Sleep_Hours_Per_Day  Social_Hours_Per_Day  \
# count          2000.000000           2000.000000
# mean              7.501250              2.704550
# std               1.460949              1.688514
# min               5.000000              0.000000
# 25%               6.200000              1.200000
# ...

# %% [markdown]
# Biases:
# * how we are measuring sleep hours
# * stress level is not objective
# * what is a physical activity
# * self-reported data may be inaccurate
# * simplified mapping for stress level
#
#
# Asumptions:
# * study per day is corelating with GPA
# * sleep and physical activity are coraleting with stress level
# * social hours are corelated with extracurriular and study hours
# * higher physical activity improves sleep quality
# * students with more extracurricular hours may have better time management skills

# %% [markdown]
# Task 2.6: Dataset division
# Divide the dataset into subsets. Randomly reserve 30% of the dataset for testing purposes
# at the end of the project. All further tasks in this instruction should be performed only on
# the remaining 70% of the data samples.

# %%
from sklearn.model_selection import train_test_split

mapping = {'Low' : 1, 'Moderate' : 2, 'High' : 3}
data['Stress_Level'] = data['Stress_Level'].map(mapping)

data_train, data_test = train_test_split(data, test_size=0.3, random_state=42)
data.describe()
# Out:
#         Student_ID  Study_Hours_Per_Day  Extracurricular_Hours_Per_Day  \
# count  2000.000000          2000.000000                    2000.000000
# mean   1000.500000             7.475800                       1.990100
# std     577.494589             1.423888                       1.155855
# min       1.000000             5.000000                       0.000000
# 25%     500.750000             6.300000                       1.000000
# 50%    1000.500000             7.400000                       2.000000
# 75%    1500.250000             8.700000                       3.000000
# max    2000.000000            10.000000                       4.000000
#
#        Sleep_Hours_Per_Day  Social_Hours_Per_Day  \
# count          2000.000000           2000.000000
# mean              7.501250              2.704550
# std               1.460949              1.688514
# min               5.000000              0.000000
# 25%               6.200000              1.200000
# ...

# %% [markdown]
# Task 2.7: Dataset visualization
# Examine your dataset, perform exploratory data analysis, and show how features are
# distributed and their relationships to each other. Prepare a Python notebook that includes
# the necessary figures.

# %%
cor = data.select_dtypes(include=[float, int]).corr()
plt.figure(figsize=(8,6))
sns.heatmap(cor, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

plt.figure(figsize=(8,6))
sns.scatterplot(data=data, x='Study_Hours_Per_Day', y='GPA', hue='Stress_Level', palette='viridis')
plt.title('Study_Hours_Per_Day vs GPA')
plt.xlabel('Study_Hours_Per_Day')
plt.ylabel('GPA')
plt.grid(True)
plt.show()

plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 1)
sns.boxplot(data=data, x='Stress_Level', y='Sleep_Hours_Per_Day')
plt.title('Sleep Hours by Stress Level')
plt.xlabel('Stress Level')
plt.ylabel('Sleep Hours Per Day')
plt.subplot(1, 3, 2)
sns.boxplot(data=data, x='Stress_Level', y='Physical_Activity_Hours_Per_Day')
plt.title('Physical Activity by Stress Level')
plt.xlabel('Stress Level')
plt.ylabel('Physical Activity Hours Per Day')
plt.subplot(1, 3, 3)
sns.boxplot(data=data, x='Stress_Level', y='Social_Hours_Per_Day')
plt.title('Social Hours by Stress Level')
plt.xlabel('Stress Level')

plt.tight_layout()
plt.show()
plt.figure(figsize=(8,6))
sns.pairplot(data, hue="Stress_Level", palette="Set2", corner=True)
plt.suptitle("Pairplot: Relationships Between Variables", y=1.02)
plt.show()

# %% [markdown]
# Task 2.8: Project task formulation
# Based on your observations, formulate research questions that will serve as potential goals
# for your project. Try to prepare several potential tasks and then discuss them with your
# teacher. Note that these tasks should not repeat those already completed in the related
# work (Task 2 should be done prior to this one).
# To complete this task, you will need at least one classification or regression problem. After
# receiving approval from the teacher, these research questions will form the final goal of
# your project.

# %% [markdown]
# Goal: Preparing a classification model that will predict stress level of the students.
#
# Tasks:
# * divide the data for two datasets one with study_per_hours and one witout
# * selecting necessary features (deleting the student_id)
# * data exploration(making plots)
# * look for patterns and data relations
# * two models classification problem
# * comparing two models
